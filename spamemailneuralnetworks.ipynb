# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/rishablahari/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/rishablahari/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
data = pd.read_csv('spam.csv')
data.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  5572 non-null   object
#  1   Message   5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
data.dropna(inplace=True)

# %%
data.loc[data['Category']=='spam','Category'] = 1
data.loc[data['Category']=='ham','Category'] = 0

# %%
stp_words=stopwords.words('english')
def clean_msg(msg): 
  cleanmsg=" ".join(word for word in msg.
                       split() if word not in stp_words)
  return cleanmsg 

data['Message']=data['Message'].apply(clean_msg)

# %%
data.head()
# Out:
#   Category                                            Message
# 0        0  Go jurong point, crazy.. Available bugis n gre...
# 1        0                      Ok lar... Joking wif u oni...
# 2        1  Free entry 2 wkly comp win FA Cup final tkts 2...
# 3        0          U dun say early hor... U c already say...
# 4        0          Nah I think goes usf, lives around though

# %%
data['Category'].value_counts()
# Out:
# 0    4825
# 1     747
# Name: Category, dtype: int64

# %%
consolidated=' '.join(word for word in data['Message'][data['Category']==1].astype(str))
wordCloud=WordCloud(width=1600,height=800,random_state=21,max_font_size=110)
plt.figure(figsize=(15,10))
plt.imshow(wordCloud.generate(consolidated),interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
cv = TfidfVectorizer(max_features=2500)
X = cv.fit_transform(data['Message'] ).toarray()

# %%
from sklearn.model_selection import train_test_split
x_train ,x_test,y_train,y_test=train_test_split(X,data['Category'], test_size=0.25 , random_state=42)

# %%
consolidated=' '.join(word for word in data['Message'][data['Category']==0].astype(str))
wordCloud=WordCloud(width=1600,height=800,random_state=21,max_font_size=110)
plt.figure(figsize=(15,10))
plt.imshow(wordCloud.generate(consolidated),interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

y_train_encoded = label_encoder.fit_transform(y_train)

model = MLPClassifier(hidden_layer_sizes=(100,), max_iter=1000, random_state=42)  


model.fit(x_train, y_train_encoded)

y_test_encoded = label_encoder.transform(y_test)

pred = model.predict(x_test)

accuracy = accuracy_score(y_test_encoded, pred)
print("Model Accuracy:", accuracy)
# Out:
# Model Accuracy: 0.9870782483847811

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

conf_matrix = confusion_matrix(y_test_encoded, pred)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
